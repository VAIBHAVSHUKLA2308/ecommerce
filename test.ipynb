# %%
from dputils.scrape import Scraper, Tag

# %%
url = "https://www.flipkart.com/search?q=shoes&page=2"

# %%
sc = Scraper(url)
target = Tag(cls='_1YokD2 _3Mn1Gg')
items = Tag(cls='_1xHGtK _373qXS')
brand = Tag(cls='_2WkVRV')
title = Tag('a',cls='IRpwTa')
rating = Tag(cls='_3LWZlK _1BLPMq')
price = Tag(cls='_30jeq3')
oprice = Tag(cls='_3I9_wc')
discount = Tag(cls='_3Ay6Sb')

# %%
sc.get_all(target, items, 
            name=title, 
            price=price, 
            rr=rating, 
            brand=brand,
            orignal_price=oprice,
            discount= discount, errors=True, info=True)
# Out:
# Found 40 items
# Extracting data...
# Extracting data for item 1...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 2...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 3...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 4...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 5...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 6...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 7...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 8...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 9...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 10...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 11...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 12...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 13...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 14...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 15...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 16...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 17...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 18...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 19...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 20...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 21...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 22...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 23...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 24...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 25...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 26...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 27...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 28...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 29...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 30...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 31...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 32...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 33...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 34...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 35...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 36...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 37...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 38...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 39...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# Extracting data for item 40...
# Error for tag=ℹ️--[tag: div attrs: {'class': '_3LWZlK _1BLPMq'} output: text]-- -> 'NoneType' object has no attribute 'text'
# [{'name': 'shoes Walking Shoes For Men',
#   'price': '₹399',
#   'brand': 'WAAN',
#   'orignal_price': '₹1,999',
#   'discount': '80% off'},
#  {'name': 'Combo Pack Of 5 Casual Shoes Canvas Shoes For Men',
#   'price': '₹699',
#   'brand': 'BRUTON',
#   'orignal_price': '₹3,780',
#   'discount': '81% off'},
#  {'name': 'Modern Trendy Shoes Sneakers For Men',
#   'price': '₹249',
#   'brand': 'BRUTON',
#   'orignal_price': '₹1,299',
#   'discount': '80% off'},
#  {'name': 'Running Shoes For Men',
#   'price': '₹299',
#   'brand': 'aadi',
#   'orignal_price': '₹999',
#   'discount': '70% off'},
#  {'name': 'Mesh Running Shoes For Men',
#   'price': '₹399',
#   'brand': 'aadi',
#   'orignal_price': '₹999',
#   'discount': '60% off'},
#  {'name': 'Running Shoes For Men',
#   'price': '₹1,557',
#   'brand': 'REEBOK',
#   'orignal_price': '₹3,799',
#   'discount': '59% off'},
#  {'name': 'Lightweight,Comfort,Summer,Trendy,Walking,Outdoor,Styli...',
#   'price': '₹419',
#   'brand': 'aadi',
#   'orignal_price': '₹1,999',
#   'discount': '79% off'},
#  {'name': 'Exclusive Affordable Collection of Trendy & Stylish Cas...',
#   'price': '₹229',
#   'brand': 'World Wear Footwear',
#   'orignal_price': '₹1,490',
#   'discount': '84% off'},
#  {'name': 'FAST Trendy Trainer Execellent Running Gear Lace-Ups Sp...',
#   'price': '₹299',
#   'brand': 'HOTSTYLE',
#   'orignal_price': '₹1,499',
#   'discount': '80% off'},
#  {'name': 'Trendy Sports Running Running Shoes For Men',
#   'price': '₹299',
#   'brand': 'BRUTON',
#   'orignal_price': '₹1,299',
#   'discount': '76% off'},
#  {'name': 'Combo Pack Of 4 Casual Shoes Loafer Shoes Sneakers For ...',
#   'price': '₹499',
#   'brand': 'BRUTON',
#   'orignal_price': '₹3,635',
#   'discount': '86% off'},
#  {'name': 'Sneakers For Men',
#   'price': '₹579',
#   'brand': 'RapidBox',
#   'orignal_price': '₹999',
#   'discount': '42% off'},
#  {'name': 'Mesh| Ultralightweight| Premiun| Comfort| Summer Tendy|...',
#   'price': '₹499',
#   'brand': 'aadi',
#   'orignal_price': '₹1,999',
#   'discount': '75% off'},
#  {'name': 'Nexon-13 White Sports,Walking,Training,Gym,Stylish, Run...',
#   'price': '₹614',
#   'brand': 'asian',
#   'orignal_price': '₹1,199',
#   'discount': '48% off'},
#  {'name': 'Pictor M Running Shoes For Men',
#   'price': '₹1,755',
#   'brand': 'ADIDAS',
#   'orignal_price': '₹4,999',
#   'discount': '64% off'},
#  {'name': 'Casual Loafers For Men',
#   'price': '₹293',
#   'brand': 'AJANTA',
#   'orignal_price': '₹699',
#   'discount': '58% off'},
#  {'name': 'FIRST Running Shoes For Men',
#   'price': '₹1,329',
#   'brand': 'CAMPUS',
#   'orignal_price': '₹1,799',
#   'discount': '26% off'},
#  {'name': 'Running Shoes For Men',
#   'price': '₹1,099',
#   'brand': 'asian',
#   'orignal_price': '₹1,999',
#   'discount': '45% off'},
#  {'name': 'ROYCE-2 Running Shoes For Men',
#   'price': '₹888',
#   'brand': 'CAMPUS',
#   'orignal_price': '₹1,099',
#   'discount': '19% off'},
#  {'name': 'Lightweight,Comfort,Summer,Trendy,Walking,Outdoor,Styli...',
#   'price': '₹299',
#   'brand': 'aadi',
#   'orignal_price': '₹1,999',
#   'discount': '85% off'},
#  {'name': 'Combo Pack of 2 Sports Shoes Running Shoes For Men Runn...',
#   'price': '₹499',
#   'brand': 'BRUTON',
#   'orignal_price': '₹2,499',
#   'discount': '80% off'},
#  {'name': 'CAMP KRIPTO Running Shoes For Men',
#   'price': '₹1,332',
#   'brand': 'CAMPUS',
#   'orignal_price': '₹1,699',
#   'discount': '21% off'},
#  {'name': 'Nexon-13 Navy Sports,Walking,Training,Gym,Stylish, Runn...',
#   'price': '₹614',
#   'brand': 'asian',
#   'orignal_price': '₹1,199',
#   'discount': '48% off'},
#  {'name': 'CUBIC_1 Running Shoes For Men',
#   'price': '₹299',
#   'brand': 'BRUTON',
#   'orignal_price': '₹1,299',
#   'discount': '76% off'},
#  {'name': 'Thunder-01 White Color Change Sneakers,Casuals,Loafer S...',
#   'price': '₹774',
#   'brand': 'asian',
#   'orignal_price': '₹1,699',
#   'discount': '54% off'},
#  {'name': 'Thar-01 Blue Sneakers,Sports,Training,Gym,Walking,Styli...',
#   'price': '₹549',
#   'brand': 'asian',
#   'orignal_price': '₹1,249',
#   'discount': '56% off'},
#  {'name': 'Sneakers For Men',
#   'price': '₹579',
#   'brand': 'RapidBox',
#   'orignal_price': '₹999',
#   'discount': '42% off'},
#  {'name': 'Trendy Sports Running Running Shoes For Men',
#   'price': '₹299',
#   'brand': 'BRUTON',
#   'orignal_price': '₹1,299',
#   'discount': '76% off'},
#  {'name': 'BARLEY Running Shoes For Men',
#   'price': '₹999',
#   'brand': 'CAMPUS',
#   'orignal_price': '₹1,299',
#   'discount': '23% off'},
#  {'name': 'Trendy Sports Running Running Shoes For Men',
#   'price': '₹299',
#   'brand': 'BRUTON',
#   'orignal_price': '₹1,299',
#   'discount': '76% off'},
#  {'name': 'Mesh |Lightweight|Comfort|Summer|Trendy|Walking|Outdoor...',
#   'price': '₹299',
#   'brand': 'aadi',
#   'orignal_price': '₹999',
#   'discount': '70% off'},
#  {'name': 'Modern Trendy Sneakers Shoes Sneakers For Men',
#   'price': '₹299',
#   'brand': 'BRUTON',
#   'orignal_price': '₹1,299',
#   'discount': '76% off'},
#  {'name': 'wndr-13 sports shoes for men | Latest Stylish Casual sp...',
#   'price': '₹499',
#   'brand': 'asian',
#   'orignal_price': '₹699',
#   'discount': '28% off'},
#  {'name': 'Synthetic Leather |Lightweight|Comfort|Summer|Trendy|Wa...',
#   'price': '₹449',
#   'brand': 'aadi',
#   'orignal_price': '₹999',
#   'discount': '55% off'},
#  {'name': 'Premium Sports Shoes for Women Walking Shoes For Women',
#   'price': '₹349',
#   'brand': 'BIRDE',
#   'orignal_price': '₹999',
#   'discount': '65% off'},
#  {'name': 'Loafers For Men',
#   'price': '₹649',
#   'brand': 'Bata',
#   'orignal_price': '₹999',
#   'discount': '35% off'},
#  {'name': 'Combo Pack Of 2 Casual Shoes Sneakers For Men Sneakers ...',
#   'price': '₹499',
#   'brand': 'BRUTON',
#   'orignal_price': '₹2,499',
#   'discount': '80% off'},
#  {'name': 'Comfortable and Light Weight sports shoes for men and b...',
#   'price': '₹279',
#   'brand': 'Elevarse',
#   'orignal_price': '₹899',
#   'discount': '68% off'},
#  {'name': 'Trendy Sport Shoes For Men Pack Of 2 Running Shoes For ...',
#   'price': '₹499',
#   'brand': 'BIRDE',
#   'orignal_price': '₹1,498',
#   'discount': '66% off'},
#  {'name': 'Running Shoes For Men',
#   'price': '₹637',
#   'brand': 'Arivo',
#   'orignal_price': '₹2,199',
#   'discount': '71% off'}]
